# %% [markdown]
# # **Project Name**    - **Entertainer Data Analysis**
#
# ![hand-drawn-doodle-movie-cinema-set_88138-1050.avif](data:image/avif;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project aims to conduct Data Analysis on a dataset containing information about various entertainers, including musicians, actors, and television personalities. The dataset includes details such as the year of breakthrough, major works, awards nominations, gender, birth year, and year of death (if applicable) for each entertainer. By analyzing this dataset, we seek to uncover patterns, trends, and insights into the careers of these entertainers, identifying factors that contribute to their success and longevity in the entertainment industry.

# %% [markdown]
# ### Import Libraries

# %%
#import all library that will be used in entire project
import numpy as np                               #importing numpy
import pandas as pd                              #imporing pandas
import matplotlib.pyplot as plt                  #imporitng matplotlib
import seaborn as sns                            #importing seaborn

# %% [markdown]
# ### Dataset Loading

# %%
#Mount google drive for access the dataset of Entertainer
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#File path of Entertainer dataset in google drive
file_path = "/content/drive/MyDrive/Entertainer Data Analytics_DataSet/Entertainer-Basic-Info.csv"
BasicInfo_df = pd.read_csv(file_path)

# %%
file_path = "/content/drive/MyDrive/Entertainer Data Analytics_DataSet/Entertainer-Breakthrough-Info.csv"
BreakthroughInfo_df = pd.read_csv(file_path)

# %%
file_path = "/content/drive/MyDrive/Entertainer Data Analytics_DataSet/Entertainer-Last-work-Info.csv"
LastWorkInfo_df = pd.read_csv(file_path)

# %%
file_path = "/content/drive/MyDrive/imdb_top_1000.csv"
Imdb_df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
BasicInfo_df.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year
# 0            Adele                    F        1988
# 1   Angelina Jolie                    F        1975
# 2  Aretha Franklin                    F        1942
# 3      Bette Davis                    F        1908
# 4      Betty White                    F        1922

# %%
BreakthroughInfo_df.head()
# Out:
#        Entertainer  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0            Adele                                          2008
# 1   Angelina Jolie                                          1999
# 2  Aretha Franklin                                          1967
# 3      Bette Davis                                          1934
# 4      Betty White                                          1952
#
#                           Breakthrough Name  Year of First Oscar/Grammy/Emmy
# 0                                        19                           2009.0
# 1                         Girl, Interrupted                           1999.0
# 2  I Never Loved a Man (The Way I Love You)                           1968.0
# 3                          Of Human Bondage                           1935.0
# 4                      Life with Elilzabeth                           1976.0

# %%
LastWorkInfo_df.head()
# Out:
#        Entertainer  Year of Last Major Work (arguable)  Year of Death
# 0            Adele                                2016            NaN
# 1   Angelina Jolie                                2016            NaN
# 2  Aretha Franklin                                2014            NaN
# 3      Bette Davis                                1989         1989.0
# 4      Betty White                                2016            NaN

# %%
Imdb_df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
# Selecting specific columns from the IMDb dataset
selected_columns = ['Runtime', 'Genre', 'IMDB_Rating', 'Meta_score', 'Gross', 'Director']
Imdb_df = Imdb_df[selected_columns]

# %% [markdown]
# Now let's join all the DataSet based on columns.

# %%
# Assuming BasicInfo_df, BreakthroughInfo_df, and LastWorkInfo_df are your existing DataFrames
# Assuming Imdb_df contains IMDb data
# Merging the data based on common data set for IMDB data

# Merge IMDb data with BasicInfo_df using 'inner' join
Final_data = pd.merge(BasicInfo_df, Imdb_df, left_index=True, right_index=True, how='inner')

# Merge with BreakthroughInfo_df using 'inner' join
Final_data = pd.merge(Final_data, BreakthroughInfo_df, left_index=True, right_index=True, how='inner')

# Merge with LastWorkInfo_df using 'inner' join
Final_data = pd.merge(Final_data, LastWorkInfo_df, left_index=True, right_index=True, how='inner')

# Print or inspect merged_data to verify the merged DataFrame
Final_data
# Out:
#       Entertainer_x Gender (traditional)  Birth Year  Runtime  \
# 0             Adele                    F        1988  142 min
# 1    Angelina Jolie                    F        1975  175 min
# 2   Aretha Franklin                    F        1942  152 min
# 3       Bette Davis                    F        1908  202 min
# 4       Betty White                    F        1922   96 min
# ..              ...                  ...         ...      ...
# 65        Tom Hanks                    M        1956  165 min
# 66     Tony Bennett                    M        1926   98 min
# 67     Wayne Newton                    M        1942  137 min
# 68       Will Smith                    M        1968  101 min
# 69    Willie Nelson                    M        1933  113 min
#
#                            Genre  IMDB_Rating  Meta_score        Gross  \
# 0                          Drama          9.3        80.0   28,341,469
# 1                   Crime, Drama          9.2       100.0  134,966,411
# ...

# %%
Final_data.head()
# Out:
#      Entertainer_x Gender (traditional)  Birth Year  Runtime  \
# 0            Adele                    F        1988  142 min
# 1   Angelina Jolie                    F        1975  175 min
# 2  Aretha Franklin                    F        1942  152 min
# 3      Bette Davis                    F        1908  202 min
# 4      Betty White                    F        1922   96 min
#
#                   Genre  IMDB_Rating  Meta_score        Gross  \
# 0                 Drama          9.3        80.0   28,341,469
# 1          Crime, Drama          9.2       100.0  134,966,411
# 2  Action, Crime, Drama          9.0        84.0  534,858,444
# 3          Crime, Drama          9.0        90.0   57,300,000
# 4          Crime, Drama          9.0        96.0    4,360,000
#
#                Director    Entertainer_y  \
# 0        Frank Darabont            Adele
# 1  Francis Ford Coppola   Angelina Jolie
# 2     Christopher Nolan  Aretha Franklin
# 3  Francis Ford Coppola      Bette Davis
# ...

# %% [markdown]
# Droping Duplicate Columns

# %%
# Drop additional columns in the code
Final_data.drop(['Entertainer','Entertainer_y'], axis = 1, inplace = True)
Final_data = Final_data.rename(columns ={'Entertainer_x': 'Entertainer'})

# %%
Final_data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  Runtime  \
# 0            Adele                    F        1988  142 min
# 1   Angelina Jolie                    F        1975  175 min
# 2  Aretha Franklin                    F        1942  152 min
# 3      Bette Davis                    F        1908  202 min
# 4      Betty White                    F        1922   96 min
#
#                   Genre  IMDB_Rating  Meta_score        Gross  \
# 0                 Drama          9.3        80.0   28,341,469
# 1          Crime, Drama          9.2       100.0  134,966,411
# 2  Action, Crime, Drama          9.0        84.0  534,858,444
# 3          Crime, Drama          9.0        90.0   57,300,000
# 4          Crime, Drama          9.0        96.0    4,360,000
#
#                Director  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0        Frank Darabont                                          2008
# 1  Francis Ford Coppola                                          1999
# ...

# %% [markdown]
# Missing values/Null values

# %%
#Checking the missing / Null values
Final_data.isnull().sum()
# Out:
# Entertainer                                      0
# Gender (traditional)                             0
# Birth Year                                       0
# Runtime                                          0
# Genre                                            0
# IMDB_Rating                                      0
# Meta_score                                       5
# Gross                                            7
# Director                                         0
# Year of Breakthrough/#1 Hit/Award Nomination     0
# Breakthrough Name                                0
# Year of First Oscar/Grammy/Emmy                  6
# Year of Last Major Work (arguable)               0
# Year of Death                                   40
# dtype: int64

# %% [markdown]
# After observing the Data set we can say there are 6 missing data in the Year of First Oscar/Grammy/Emmy, 40 missing data in the column Year of Death, 5 missing data from the column Meta_score and 7 from Gross column.

# %% [markdown]
# Firstly converting the decimal type number into proper interger fomat, from the given columns Year of First Oscar/ Grammy / Emmy awards and Year of Death.

# %%
#Convert columns to integers
Final_data['Year of First Oscar/Grammy/Emmy'] = Final_data['Year of First Oscar/Grammy/Emmy'].astype(float).astype('Int64')
Final_data['Year of Death'] = Final_data['Year of Death'].astype(float).astype('Int64')

# %% [markdown]
# Replacing the Null / Missing values with some content

# %%
Final_data['Year of First Oscar/Grammy/Emmy'] = Final_data['Year of First Oscar/Grammy/Emmy'].astype('object')
Final_data['Year of Death'] = Final_data['Year of Death'].astype('object')

#Filling the missing/null data with some content.
Final_data.fillna({'Year of First Oscar/Grammy/Emmy': 'Not Available', 'Year of Death': 'Alive', 'Meta_score': 'Not available', 'Gross': 0}, inplace=True)

# %%
#Again checking for null values
Final_data.isnull().sum()
# Out:
# Entertainer                                     0
# Gender (traditional)                            0
# Birth Year                                      0
# Runtime                                         0
# Genre                                           0
# IMDB_Rating                                     0
# Meta_score                                      0
# Gross                                           0
# Director                                        0
# Year of Breakthrough/#1 Hit/Award Nomination    0
# Breakthrough Name                               0
# Year of First Oscar/Grammy/Emmy                 0
# Year of Last Major Work (arguable)              0
# Year of Death                                   0
# dtype: int64

# %%
#Dataset Info and check how many entries are there left after cleaning the data
Final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 14 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Entertainer                                   70 non-null     object
#  1   Gender (traditional)                          70 non-null     object
#  2   Birth Year                                    70 non-null     int64
#  3   Runtime                                       70 non-null     object
#  4   Genre                                         70 non-null     object
#  5   IMDB_Rating                                   70 non-null     float64
#  6   Meta_score                                    70 non-null     object
#  7   Gross                                         70 non-null     object
#  8   Director                                      70 non-null     object
# ...

# %%
#Counting the number of rows and column after cleaning the data set
row, columns = Final_data.shape
print(f"No of rows: {row}")
print(f"No of columns: {columns}")
# Out:
# No of rows: 70
# No of columns: 14

# %%
#Data set view after cleaning
Final_data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  Runtime  \
# 0            Adele                    F        1988  142 min
# 1   Angelina Jolie                    F        1975  175 min
# 2  Aretha Franklin                    F        1942  152 min
# 3      Bette Davis                    F        1908  202 min
# 4      Betty White                    F        1922   96 min
#
#                   Genre  IMDB_Rating Meta_score        Gross  \
# 0                 Drama          9.3       80.0   28,341,469
# 1          Crime, Drama          9.2      100.0  134,966,411
# 2  Action, Crime, Drama          9.0       84.0  534,858,444
# 3          Crime, Drama          9.0       90.0   57,300,000
# 4          Crime, Drama          9.0       96.0    4,360,000
#
#                Director  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0        Frank Darabont                                          2008
# 1  Francis Ford Coppola                                          1999
# ...

# %% [markdown]
# This much Data are not enough to do the analysis. So, I have downloaded more data from IMDB data set Universal library.

# %%
# !pip install imdbpy
# !pip install openpyxl
import imdb
mi = imdb.Cinemagoer()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.2/297.2 kB 5.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# Creating lists to store the extracted data of Persons like number of films act, height, quotes, pics from IMDB data set.

# %%
pics = []
num_films_act = []
quotes = []
height = []

for i in range(len(BasicInfo_df)):
    ent_name = BasicInfo_df.Entertainer[i]
    print("Starting-->", ent_name)
    people = mi.search_person(ent_name)
    if len(people):
        try:
            per = mi.get_person(people[0].personID)
        except:
            per = people[0]

        keys = per.keys()

        #Picture of the person
        if "full-size headshot" in keys:
            pics.append(per["full-size headshot"])
        elif "headshot" in keys:
            pics.append(per["headshot"])
        else:
            pics.append("NA")

        #count of flims acted
        if "filmography" in keys:
            if "actor" in per["filmography"]:
                num_films_act.append(len(per["filmography"]["actor"]))
            elif "actress" in per["filmography"]:
                num_films_act.append(len(per["filmography"]["actress"]))
            else:
                num_films_act.append(0)
        else:
            num_films_act.append(0)

        #height
        if "height" in keys:
            height.append(per["height"])
        else:
            height.append("NA")

        #Quotes
        if "quotes" in keys:
            quotes.append(per["quotes"][0])
        else:
            quotes.append("NA")
    else:
        height.append("Np")
        pics.append("Np")
        num_films_act.append("Np")
        quotes.append("Np")

    print("Done----->", ent_name)
    print("    ")
# Out:
# Done-----> Justin Timberlake
#
# Starting--> Katherine Hepburn
# Done-----> Katherine Hepburn
#
# Starting--> Keifer Sutherland
# Done-----> Keifer Sutherland
#
# Starting--> Kirk Douglas
# Done-----> Kirk Douglas
#
# Starting--> Lady Gaga
# Done-----> Lady Gaga
#
# Starting--> Leonard Bernstein
# Done-----> Leonard Bernstein
#
# Starting--> Leonardo DiCaprio
# Done-----> Leonardo DiCaprio
#
# Starting--> Louis Armstrong
# Done-----> Louis Armstrong
#
# Starting--> Madonna
# Done-----> Madonna
#
# Starting--> Mariah Carey
# Done-----> Mariah Carey
#
# Starting--> Marlon Brando
# Done-----> Marlon Brando
#
# Starting--> Mary Tyler Moore
# Done-----> Mary Tyler Moore
#
# Starting--> Meryl Streep
# Done-----> Meryl Streep
#
# Starting--> Mick Jagger
# Done-----> Mick Jagger
#
# Starting--> Morgan Freeman
# Done-----> Morgan Freeman
#
# Starting--> Oprah Winfrey
# ...

# %%
#Checking the data length
print(len(pics))
print(len(height))
print(len(num_films_act))
print(len(quotes))
# Out:
# 70
# 70
# 70
# 70

# %%
#Adding the extracted data to the final data set
Final_data["Picture"] = pics
Final_data["Height"] = height
Final_data["Number_films_act"] = num_films_act
Final_data["Quote"] = quotes

# %%
Final_data
# Out:
#         Entertainer Gender (traditional)  Birth Year  Runtime  \
# 0             Adele                    F        1988  142 min
# 1    Angelina Jolie                    F        1975  175 min
# 2   Aretha Franklin                    F        1942  152 min
# 3       Bette Davis                    F        1908  202 min
# 4       Betty White                    F        1922   96 min
# ..              ...                  ...         ...      ...
# 65        Tom Hanks                    M        1956  165 min
# 66     Tony Bennett                    M        1926   98 min
# 67     Wayne Newton                    M        1942  137 min
# 68       Will Smith                    M        1968  101 min
# 69    Willie Nelson                    M        1933  113 min
#
#                            Genre  IMDB_Rating     Meta_score        Gross  \
# 0                          Drama          9.3           80.0   28,341,469
# ...

# %%
#After finding that height and Quote column have no data so I drop the columns
Final_data.drop(['Height', 'Quote'], axis=1, inplace=True)

# %%
Final_data.head()
# Out:
#        Entertainer Gender (traditional)  Birth Year  Runtime  \
# 0            Adele                    F        1988  142 min
# 1   Angelina Jolie                    F        1975  175 min
# 2  Aretha Franklin                    F        1942  152 min
# 3      Bette Davis                    F        1908  202 min
# 4      Betty White                    F        1922   96 min
#
#                   Genre  IMDB_Rating Meta_score        Gross  \
# 0                 Drama          9.3       80.0   28,341,469
# 1          Crime, Drama          9.2      100.0  134,966,411
# 2  Action, Crime, Drama          9.0       84.0  534,858,444
# 3          Crime, Drama          9.0       90.0   57,300,000
# 4          Crime, Drama          9.0       96.0    4,360,000
#
#                Director  Year of Breakthrough/#1 Hit/Award Nomination  \
# 0        Frank Darabont                                          2008
# 1  Francis Ford Coppola                                          1999
# ...

# %% [markdown]
# ###After cleaning the data and handling missing values, the final DataFrame **Final_data** was converted into a CSV file for further analysis.

# %%
Final_data.to_csv('Final_Entertainer_data.csv')

# %% [markdown]
# Create a different CSV file for actor and actress names, movies names and publish year of movies for all the actor and actress.

# %%
#List for actor names, movies and publish year of the movies
actor = []
movie_title = []
year = []

#Function to get all the actor and actress name, movies done and movie publish year from IMDB
for i in range(len(BasicInfo_df)):
    ent_name = BasicInfo_df.Entertainer[i]
    leen = len(movie_title)
    print("Start-->", ent_name)
    persons = mi.search_person(ent_name)
    try:
        per = mi.get_person(persons[0].personID)
        if 'filmography' in per.keys():
            ma_keys = per["filmography"].keys()
            if "actor" in ma_keys:
                act = per["filmography"]["actor"]

                for j in range(len(act)):
                    movi = mi.get_movie(act[j].movieID)
                    k = movi.keys()
                    actor.append(ent_name)
                    if "title" in k:
                        movie_title.append(movi["title"])
                    else:
                        movie_title.append("NA")

                    if "year" in k:
                        year.append(movi["year"])
                    else:
                        year.append("NA")

            elif "actress" in  ma_keys:
                act = per["filmography"]["actress"]

                for j in range(len(act)):
                    movi = mi.get_movie(act[j].movieID)
                    k = movi.keys()
                    actor.append(ent_name)
                    if "title" in k:
                        movie_title.append(movi["title"])
                    else:
                        movie_title.append("NA")

                    if "year" in k:
                        year.append(movi["year"])
                    else:
                        year.append("NA")
            else:
                actor.append(ent_name)
                movie_title.append("NA")
                year.append("NA")
        else:
            actor.append(ent_name)
            movie_title.append("NA")
            year.append("NA")
    except:
        actor.append(ent_name)
        movie_title.append("NA")
        year.append("NA")
    print("Done-->", ent_name, " Added--> ", len(movie_title)-leen, " Movies")
    print("   ")
# Out:
# Done--> Paul Newman  Added-->  84  Movies
#
# Start--> Peter O'Toole
# Done--> Peter O'Toole  Added-->  102  Movies
#
# Start--> Prince
# Done--> Prince  Added-->  81  Movies
#
# Start--> Robert Redford
# Done--> Robert Redford  Added-->  83  Movies
#
# Start--> Sidney Poitier
# Done--> Sidney Poitier  Added-->  57  Movies
#
# Start--> Sly Stone
# Done--> Sly Stone  Added-->  1  Movies
#
# Start--> Stevie Wonder
# Done--> Stevie Wonder  Added-->  34  Movies
#
# Start--> Tom Hanks
# Done--> Tom Hanks  Added-->  98  Movies
#
# Start--> Tony Bennett
# Done--> Tony Bennett  Added-->  33  Movies
#
# Start--> Wayne Newton
# Done--> Wayne Newton  Added-->  49  Movies
#
# Start--> Will Smith
# Done--> Will Smith  Added-->  92  Movies
#
# Start--> Willie Nelson
# Done--> Willie Nelson  Added-->  138  Movies

# %%
#Checking the data length
print(len(actor))
print(len(movie_title))
print(len(year))
# Out:
# 4879
# 4879
# 4879

# %%
#Convert the list into a proper Dataframe format
Actors_films_list_df = pd.DataFrame({"Actor Name":actor, "Movie Title":movie_title, " Year of Publish":year})

# %% [markdown]
# Convert the final data set of actor names and movies publish year to CSV file.

# %%
Actors_films_list_df.to_csv("Actors_films_list.csv")

# %% [markdown]
# Collection of Number of awards received, nominated actor and Oscars award received.

# %% [markdown]
# ##**Conclusion**

# %% [markdown]
# The data processing workflow undertaken effectively addressed several key aspects of data management and enrichment.
#
# * Data Cleaning: Duplicate columns were successfully identified and removed, ensuring data integrity and eliminating redundancy. Unwanted columns such as 'Height' and 'Quote' were dropped, streamlining the dataset for further analysis.
#
# * Data Type Conversion: The conversion of data types, particularly for 'Year of First Oscar/Grammy/Emmy' and 'Year of Death', was pivotal for ensuring uniformity and facilitating numerical operations on these fields.
#
# * Error Handling and Data Enrichment: Despite encountering challenges during the enrichment process, efforts were made to retrieve additional information such as movie director names from IMDb. However, unforeseen issues like connectivity problems and missing data hindered the complete execution of this task.
#
# * Handling Missing Values: Missing values were appropriately handled by replacing them with meaningful placeholders like 'Not Available', ensuring that the dataset remains informative and comprehensive.
#
# * Next Steps: Moving forward, there is an opportunity to explore alternative data sources or refine the data retrieval process to overcome the challenges encountered during data enrichment. Additionally, further analysis could be conducted to extract valuable insights from the enriched dataset, potentially uncovering hidden patterns or correlations.
